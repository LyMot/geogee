# %%
from geogee.utils import random_string
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from geogee.utils import random_string
#
# File c:\users\sarath_kin\geogee\geogee\__init__.py:7
#       4 __email__ = 'lymot101@gmail.com'
#       5 __version__ = '0.0.4'
# ----> 7 from .geogee import *
#       8 # from .utils import *
#
# File c:\users\sarath_kin\geogee\geogee\geogee.py:7
#       4 import json
#       5 # import random
#       6 # import string
# ----> 7 from utils import random_string
#       8 import ee
#       9 import shapefile
#
# ModuleNotFoundError: No module named 'utils'

# %%
random_string(string_length=6, use_seed=False)

# %%
import geogee

# %%
geogee.random_string()
