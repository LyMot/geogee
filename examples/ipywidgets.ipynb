# %% [markdown]
# **Introduction to ipywidgets**
#
# https://ipywidgets.readthedocs.io
#
# https://gishub.org/gee-ngrok

# %% [markdown]
# ## Import libraries

# %%
# !pip install geodemo

# %%
import ee
import geogee
import ipywidgets as widgets
from ipyleaflet import WidgetControl
# Out:
# C:\Users\Sarath_Kin\miniconda3\envs\demo\lib\site-packages\google\api_core\_python_version_support.py:237: FutureWarning: You are using a non-supported Python version (3.8.20). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'

# %% [markdown]
# ## Create an interactive map

# %%
Map = geogee.Map()
Map
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# ## Add Earth Engine data
#
# ### Add raster data

# %%
geogee.ee_initialize()

# %%
dem = ee.Image('USGS/SRTMGL1_003')

vis_params = {
  'min': 0,
  'max': 4000,
  'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']}

Map.addLayer(dem, vis_params, 'DEM')

# %% [markdown]
# ### Add vector data

# %%
fc = ee.FeatureCollection('TIGER/2018/States')
Map.addLayer(fc, {}, 'US States')

# %% [markdown]
# ## Change layer opacity

# %%
Map
# Out:
# Map(bottom=1801.0, center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_titl…

# %%
Map.layers
# Out:
# (TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap.Mapnik', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://tile.openstreetmap.org/{z}/{x}/{y}.png'),
#  TileLayer(attribution='Google', name='Google Maps', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}'),
#  TileLayer(attribution='Google Earth Engine', name='DEM', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://earthengine.googleapis.com/v1/projects/1004110614441/maps/82302bf76471cbc4d71eafdc4e3c615a-bcaa0cc479f61e1a6c520eb5e881e23a/tiles/{z}/{x}/{y}'),
#  TileLayer(attribution='Google Earth Engine', name='US States', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://earthengine.googleapis.com/v1/projects/1004110614441/maps/e245cd3ed5ba82783b77fde101f5d7d8-475407b93ca8bbb48cd531a180fe9e57/tiles/{z}/{x}/{y}'))

# %%
dem_layer = Map.layers[2]
dem_layer.interact(opacity=(0, 1, 0.1))
# Out:
# Box(children=(FloatSlider(value=1.0, description='opacity', max=1.0),))

# %%
vector_layer = Map.layers[3]
vector_layer.interact(opacity=(0, 1, 0.1))
# Out:
# Box(children=(FloatSlider(value=1.0, description='opacity', max=1.0),))

# %% [markdown]
# ## Widget list
#
# Widget list: https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html
#
# Icons: https://fontawesome.com/v4.7.0/icons
#
# ### Numeric widgets
#
# #### IntSlider

# %%
int_slider = widgets.IntSlider(
    value=2000,
    min=1984,
    max=2020,
    step=1,
    description='Year:'
)
int_slider
# Out:
# IntSlider(value=2000, description='Year:', max=2020, min=1984)

# %%
int_slider.value
# Out:
# 2000

# %% [markdown]
# #### FloatSlider

# %%
float_slider = widgets.FloatSlider(
    value=0,
    min=-1,
    max=1,
    step=0.05,
    description='Threshold:'
)
float_slider
# Out:
# FloatSlider(value=0.0, description='Threshold:', max=1.0, min=-1.0, step=0.05)

# %%
float_slider.value
# Out:
# 0.0

# %% [markdown]
# #### IntProgress

# %%
int_progress = widgets.IntProgress(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Loading:',
    bar_style='', # 'success', 'info', 'warning', 'danger' or ''
    orientation='horizontal'
)
int_progress
# Out:
# IntProgress(value=7, description='Loading:', max=10)

# %%
int_text = widgets.IntText(
    value=7,
    description='Any:',
)
int_text
# Out:
# IntText(value=7, description='Any:')

# %%
float_text = widgets.FloatText(
    value=7.5,
    description='Any:',
)
float_text
# Out:
# FloatText(value=7.5, description='Any:')

# %% [markdown]
# ### Boolean widgets
#
# #### ToggleButton

# %%
toggle_button = widgets.ToggleButton(
    value=False,
    description='Click me',
    disabled=False,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
toggle_button
# Out:
# ToggleButton(value=False, button_style='success', description='Click me', icon='check', tooltip='Description')

# %%
toggle_button.value
# Out:
# False

# %% [markdown]
# #### Checkbox

# %%
checkbox = widgets.Checkbox(
    value=False,
    description='Check me',
    disabled=False,
    indent=False
)
checkbox
# Out:
# Checkbox(value=False, description='Check me', indent=False)

# %%
checkbox.value
# Out:
# False

# %% [markdown]
# ### Selection widgets
#
# #### Dropdown

# %%
dropdown = widgets.Dropdown(
    options=['USA', 'Canada', 'Mexico'],
    value='Canada',
    description='Country:'
)
dropdown
# Out:
# Dropdown(description='Country:', index=1, options=('USA', 'Canada', 'Mexico'), value='Canada')

# %%
dropdown.value
# Out:
# 'Canada'

# %% [markdown]
# #### RadioButtons

# %%
radio_buttons = widgets.RadioButtons(
    options=['USA', 'Canada', 'Mexico'],
    value='Canada',
    description='Country:'
)
radio_buttons
# Out:
# RadioButtons(description='Country:', index=1, options=('USA', 'Canada', 'Mexico'), value='Canada')

# %%
radio_buttons.value
# Out:
# 'Canada'

# %% [markdown]
# ### String widgets
#
# #### Text

# %%
text = widgets.Text(
    value='USA',
    placeholder='Enter a country name',
    description='Country:',
    disabled=False
)
text
# Out:
# Text(value='USA', description='Country:', placeholder='Enter a country name')

# %%
text.value
# Out:
# 'USA'

# %% [markdown]
# #### Textarea

# %%
widgets.Textarea(
    value='Hello World',
    placeholder='Type something',
    description='String:',
    disabled=False
)
# Out:
# Textarea(value='Hello World', description='String:', placeholder='Type something')

# %% [markdown]
# #### HTML

# %%
widgets.HTML(
    value="Hello <b>World</b>",
    placeholder='Some HTML',
    description='Some HTML',
)
# Out:
# HTML(value='Hello <b>World</b>', description='Some HTML', placeholder='Some HTML')

# %%
widgets.HTML(
    value='<img src="https://earthengine.google.com/static/images/earth-engine-logo.png" width="100" height="100">'
)
# Out:
# HTML(value='<img src="https://earthengine.google.com/static/images/earth-engine-logo.png" width="100" height="…

# %% [markdown]
# ### Button

# %%
button = widgets.Button(
    description='Click me',
    button_style='info', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)
button
# Out:
# Button(button_style='info', description='Click me', icon='check', style=ButtonStyle(), tooltip='Click me')

# %% [markdown]
# ### Date picker

# %%
date_picker = widgets.DatePicker(
    description='Pick a Date',
    disabled=False
)
date_picker
# Out:
# DatePicker(value=None, description='Pick a Date', step=1)

# %%
date_picker.value

# %% [markdown]
# ### Color picker

# %%
color_picker = widgets.ColorPicker(
    concise=False,
    description='Pick a color',
    value='blue',
    disabled=False
)
color_picker
# Out:
# ColorPicker(value='blue', description='Pick a color')

# %%
color_picker.value
# Out:
# 'blue'

# %% [markdown]
# ### Output widget

# %%
out = widgets.Output(layout={'border': '1px solid black'})
out
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
with out:
    for i in range(10):
        print(i, 'Hello world!')

# %%
from IPython.display import YouTubeVideo
out.clear_output()
with out:
    display(YouTubeVideo('mA21Us_3m28'))
out
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
out.clear_output()
with out:
    display(widgets.IntSlider())
out
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %% [markdown]
# ## Add a widget to the map

# %%
Map = geogee.Map()

dem = ee.Image('USGS/SRTMGL1_003')
fc = ee.FeatureCollection('TIGER/2018/States')
vis_params = {
  'min': 0,
  'max': 4000,
  'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']}

Map.addLayer(dem, vis_params, 'DEM')
Map.addLayer(fc, {}, 'US States')

Map
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
output_widget = widgets.Output(layout={'border': '1px solid black'})
output_control = WidgetControl(widget=output_widget, position='bottomright')
Map.add_control(output_control)

# %%
with output_widget:
    print('Nice map!')

# %%
output_widget.clear_output()
logo = widgets.HTML(
    value='<img src="https://earthengine.google.com/static/images/earth-engine-logo.png" width="100" height="100">'
)
with output_widget:
    display(logo)

# %%
def handle_interaction(**kwargs):
    latlon = kwargs.get('coordinates')
    if kwargs.get('type') == 'click':
        Map.default_style = {'cursor': 'wait'}
        xy = ee.Geometry.Point(latlon[::-1])
        selected_fc = fc.filterBounds(xy)
        
        with output_widget:
            output_widget.clear_output()
        
            try:
                name = selected_fc.first().get('NAME').getInfo()
                usps = selected_fc.first().get('STUSPS').getInfo()
                Map.layers = Map.layers[:4]        
                geom = selected_fc.geometry()
                layer_name = name + '-' + usps
                Map.addLayer(ee.Image().paint(geom, 0, 2), {'palette': 'red'}, layer_name)  
                print(layer_name)
            except Exception as e:
                print('No feature could be found')
                Map.layers = Map.layers[:4]
            
        Map.default_style = {'cursor': 'pointer'}

Map.on_interaction(handle_interaction)
